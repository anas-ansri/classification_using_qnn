# %% [markdown]
# # Generate Quasars dataset

# %%
from tqdm.auto import tqdm
import pandas as pd

tqdm.pandas()

# Load the dataset
file_path = 'star_classification.csv'
df = pd.read_csv(file_path, encoding='ascii')

# Filter the dataset for QSO and No-QSO
qso_df = df[df['class'] == 'QSO'].sample(n=120, random_state=1)
no_qso_df = df[df['class'] != 'QSO'].sample(n=30, random_state=1)

# Check the number of entries for each class
count_qso = qso_df.shape[0]
count_no_qso = no_qso_df.shape[0]

print('Number of QSO entries:', count_qso)
print('Number of No-QSO entries:', count_no_qso)
# Out:
# Number of QSO entries: 120
# Number of No-QSO entries: 30

# %%
import os
import requests
from PIL import Image
from io import BytesIO

# Function to fetch the image from SDSS and save it
def fetch_sdss_image(row, image_type, save_dir):
    print("Row: ", row)
    # Construct the URL for the SDSS image cutout service
    url = 'http://skyserver.sdss.org/dr16/SkyServerWS/ImgCutout/getjpeg?ra=' + str(row['alpha']) + '&dec=' + str(row['delta']) + '&scale=0.2&width=64&height=64'
    response = requests.get(url)
    if response.status_code == 200:
        # Open the image and save it
        image = Image.open(BytesIO(response.content))
        obj_id = str(row['obj_ID'])
        image.save(os.path.join(save_dir, image_type + '_' + obj_id + '.jpg'))
    else:
        print('Failed to retrieve image for obj_ID ' + str(row['obj_ID']))

# Create directories for QSO and No-QSO images if they don't exist
qso_dir = 'qso_images'
no_qso_dir = 'no_qso_images'
os.makedirs(qso_dir, exist_ok=True)
os.makedirs(no_qso_dir, exist_ok=True)


no_qso_df.progress_apply(lambda row: fetch_sdss_image(row, 'No-QSO', no_qso_dir), axis=1)


# Fetch and save images for QSO
# qso_df.progress_apply(lambda row: fetch_sdss_image(row, 'QSO', qso_dir), axis=1)

# Fetch and save images for No-QSO

print('Image retrieval and saving complete.')
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Row:  obj_ID         1237670965393620736.0
# alpha                      158.88627
# delta                      18.212081
# u                           18.53873
# g                           16.71179
# r                           15.88959
# i                           15.50151
# z                            15.1892
# run_ID                          5935
# rerun_ID                         301
# cam_col                            4
# field_ID                         282
# spec_obj_ID    2919510480412239872.0
# class                         GALAXY
# redshift                    0.064894
# plate                           2593
# MJD                            54175
# fiber_ID                         189
# Name: 7356, dtype: object
# Row:  obj_ID         1237661970116838400.0
# alpha                     196.502756
# delta                       6.221412
# u                            25.9792
# g                           22.97388
# r                           20.95534
# i                           19.94467
# z                           19.43108
# run_ID                          3841
# rerun_ID                         301
# cam_col                            1
# field_ID                         211
# spec_obj_ID    5447306429718616064.0
# class                         GALAXY
# redshift                    0.493458
# plate                           4838
# MJD                            55686
# fiber_ID                         737
# Name: 78218, dtype: object
# Row:  obj_ID          1237660765367108096.0
# alpha                      114.908764
# delta                       19.600931
# u                             20.9458
# g                            19.20827
# r                            18.26533
# i                            17.80275
# z                            17.45348
# run_ID                           3560
# rerun_ID                          301
# cam_col                             5
# field_ID                           37
# spec_obj_ID    12478543423954243584.0
# class                          GALAXY
# redshift                     0.094499
# plate                           11083
# MJD                             58515
# fiber_ID                          708
# Name: 18908, dtype: object
# Row:  obj_ID         1237666301627793664.0
# alpha                      46.759649
# delta                       0.727732
# u                           20.67312
# g                            18.6729
# r                           17.56153
# i                           17.02298
# z                           16.59739
# run_ID                          4849
# rerun_ID                         301
# cam_col                            5
# field_ID                         767
# spec_obj_ID     463962608723060736.0
# class                         GALAXY
# redshift                    0.136218
# plate                            412
# MJD                            52258
# fiber_ID                         334
# Name: 49419, dtype: object
# Row:  obj_ID         1237658302742266880.0
# alpha                     161.219112
# delta                      57.283817
# u                           22.55869
# g                           25.70659
# r                           21.27297
# i                            20.1322
# z                           19.45384
# run_ID                          2987
# rerun_ID                         301
# cam_col                            2
# field_ID                          68
# spec_obj_ID    9215569202383180800.0
# class                         GALAXY
# redshift                    0.866201
# plate                           8185
# MJD                            57431
# fiber_ID                         285
# Name: 13202, dtype: object
# Row:  obj_ID         1237663785276999936.0
# alpha                      13.431139
# delta                       1.011891
# u                           22.44623
# g                           19.56808
# r                           18.10192
# i                           16.74226
# z                           15.98532
# run_ID                          4263
# rerun_ID                         301
# cam_col                            6
# field_ID                         205
# spec_obj_ID    1272428017964050432.0
# class                           STAR
# redshift                     0.00007
# plate                           1130
# MJD                            52669
# fiber_ID                         586
# Name: 18255, dtype: object
# Row:  obj_ID         1237666301092954112.0
# alpha                       51.36961
# delta                       0.278535
# u                           17.74597
# g                           15.85865
# r                           14.91479
# i                           14.44174
# z                           14.09094
# run_ID                          4849
# rerun_ID                         301
# cam_col                            4
# field_ID                         798
# spec_obj_ID     466251785405753280.0
# class                         GALAXY
# redshift                    0.022693
# plate                            414
# MJD                            51869
# fiber_ID                         470
# Name: 47940, dtype: object
# Row:  obj_ID         1237659931069252096.0
# alpha                        5.32745
# delta                      35.651432
# u                           22.22507
# g                           21.54928
# r                            21.6244
# i                           22.12073
# z                           21.16513
# run_ID                          3366
# rerun_ID                         301
# cam_col                            3
# field_ID                          30
# spec_obj_ID    8718041576545473536.0
# class                           STAR
# redshift                   -0.000823
# plate                           7743
# MJD                            58107
# fiber_ID                         722
# Name: 58622, dtype: object
# Row:  obj_ID          1237671124838253056.0
# alpha                       143.71014
# delta                       13.883599
# u                            23.76889
# g                              22.533
# r                            22.14783
# i                            21.39276
# z                            21.16592
# run_ID                           5972
# rerun_ID                          301
# cam_col                             5
# field_ID                          190
# spec_obj_ID    10791763656876251136.0
# class                          GALAXY
# redshift                     0.877074
# plate                            9585
# MJD                             57780
# fiber_ID                           47
# Name: 76393, dtype: object
# Row:  obj_ID         1237662336258606080.0
# alpha                     246.873214
# delta                       26.85055
# u                           22.44865
# g                           21.09242
# r                           19.34145
# i                           18.23676
# z                           17.82582
# run_ID                          3926
# rerun_ID                         301
# cam_col                            3
# field_ID                         147
# spec_obj_ID    1585307798109972480.0
# class                         GALAXY
# redshift                    0.547145
# plate                           1408
# MJD                            52822
# fiber_ID                         148
# Name: 42335, dtype: object
# Row:  obj_ID         1237651496295268608.0
# alpha                     120.441438
# delta                      46.701456
# u                            23.9871
# g                           20.28791
# r                           18.74399
# i                            18.0399
# z                           17.59318
# run_ID                          1402
# rerun_ID                         301
# cam_col                            4
# field_ID                         105
# spec_obj_ID    4144477227470576128.0
# class                         GALAXY
# redshift                    0.210515
# plate                           3681
# MJD                            55243
# fiber_ID                         144
# Name: 19797, dtype: object
# Row:  obj_ID         1237661150841339904.0
# alpha                     194.684587
# delta                       49.29096
# u                             20.044
# g                            19.2343
# r                           18.93328
# i                           18.84114
# z                           18.79067
# run_ID                          3650
# rerun_ID                         301
# cam_col                            3
# field_ID                          51
# spec_obj_ID    7605568877280646144.0
# class                           STAR
# redshift                   -0.000529
# plate                           6755
# MJD                            56413
# fiber_ID                         418
# Name: 92511, dtype: object
# Row:  obj_ID         1237660634391838720.0
# alpha                     179.409421
# delta                      46.385637
# u                           23.58277
# g                           21.56375
# r                           20.98112
# i                           20.82394
# z                           20.41921
# run_ID                          3530
# rerun_ID                         301
# cam_col                            1
# field_ID                         361
# spec_obj_ID    8336195459539555328.0
# class                         GALAXY
# redshift                    0.113022
# plate                           7404
# MJD                            56776
# fiber_ID                         118
# Name: 98723, dtype: object
# Row:  obj_ID          1237667781746622720.0
# alpha                      150.167368
# delta                       17.997215
# u                            22.93628
# g                            22.55095
# r                            22.15981
# i                            21.20352
# z                            21.23773
# run_ID                           5194
# rerun_ID                          301
# cam_col                             2
# field_ID                          244
# spec_obj_ID    10774899897704667136.0
# class                          GALAXY
# redshift                     0.802688
# plate                            9570
# MJD                             57805
# fiber_ID                          137
# Name: 88844, dtype: object
# Row:  obj_ID         1237662224063528704.0
# alpha                     173.384061
# delta                      38.591159
# u                           18.86411
# g                           18.01173
# r                           17.72832
# i                           17.64167
# z                           17.65944
# run_ID                          3900
# rerun_ID                         301
# cam_col                            2
# field_ID                         314
# spec_obj_ID    9956454221904893952.0
# class                           STAR
# redshift                     0.00013
# plate                           8843
# MJD                            57423
# fiber_ID                         441
# Name: 46868, dtype: object
# Row:  obj_ID         1237663785281257472.0
# alpha                      23.092496
# delta                        0.99832
# u                           19.25514
# g                           18.89743
# r                            19.1182
# i                           19.32404
# z                           19.52449
# run_ID                          4263
# rerun_ID                         301
# cam_col                            6
# field_ID                         270
# spec_obj_ID    8849608294819715072.0
# class                           STAR
# redshift                   -0.000236
# plate                           7860
# MJD                            57006
# fiber_ID                         127
# Name: 17622, dtype: object
# Row:  obj_ID         1237667781755994624.0
# alpha                     172.620733
# delta                       21.20297
# u                           22.91827
# g                           21.60146
# r                           19.60744
# i                           18.74497
# z                           18.25356
# run_ID                          5194
# rerun_ID                         301
# cam_col                            2
# field_ID                         387
# spec_obj_ID    7239547226917460992.0
# class                         GALAXY
# redshift                      0.5012
# plate                           6430
# MJD                            56299
# fiber_ID                          39
# Name: 69637, dtype: object
# Row:  obj_ID         1237665441525530880.0
# alpha                     219.473265
# delta                       25.07561
# u                           19.89056
# g                           18.34265
# r                           17.44917
# i                           16.93893
# z                           16.55399
# run_ID                          4649
# rerun_ID                         301
# cam_col                            3
# field_ID                         232
# spec_obj_ID    2408409642083313664.0
# class                         GALAXY
# redshift                    0.109041
# plate                           2139
# MJD                            53878
# fiber_ID                         399
# Name: 9329, dtype: object
# Row:  obj_ID         1237653442986049536.0
# alpha                     353.317662
# delta                        -8.6923
# u                           18.18528
# g                           16.85767
# r                           16.32991
# i                           16.12402
# z                           15.97978
# run_ID                          1855
# rerun_ID                         301
# cam_col                            6
# field_ID                          57
# spec_obj_ID    3541100697980346368.0
# class                           STAR
# redshift                   -0.000009
# plate                           3145
# MJD                            54801
# fiber_ID                         529
# Name: 31084, dtype: object
# Row:  obj_ID         1237662336259981824.0
# alpha                     249.446377
# delta                      24.738545
# u                           23.14186
# g                           20.74967
# r                           19.02109
# i                           18.38831
# z                            18.0247
# run_ID                          3926
# rerun_ID                         301
# cam_col                            3
# field_ID                         168
# spec_obj_ID    4713171586907396096.0
# class                         GALAXY
# redshift                    0.353207
# plate                           4186
# MJD                            55691
# fiber_ID                         562
# Name: 34714, dtype: object
# Row:  obj_ID         1237680296739799552.0
# alpha                     349.060549
# delta                      20.541507
# u                           21.13053
# g                           20.87055
# r                           20.80374
# i                           20.79347
# z                            20.9494
# run_ID                          8108
# rerun_ID                         301
# cam_col                            1
# field_ID                         173
# spec_obj_ID    8568130843771689984.0
# class                           STAR
# redshift                    0.000098
# plate                           7610
# MJD                            56980
# fiber_ID                         118
# Name: 50310, dtype: object
# Row:  obj_ID          1237669517437370368.0
# alpha                      349.723886
# delta                        6.887279
# u                            18.20008
# g                            17.17221
# r                            16.81949
# i                            16.69275
# z                             16.6373
# run_ID                           5598
# rerun_ID                          301
# cam_col                             3
# field_ID                           47
# spec_obj_ID    12716046455695235072.0
# class                            STAR
# redshift                    -0.000027
# plate                           11294
# MJD                             58451
# fiber_ID                          483
# Name: 77763, dtype: object
# Row:  obj_ID         1237658192149086464.0
# alpha                     128.417553
# delta                      33.296485
# u                            23.5129
# g                           21.23814
# r                            19.6757
# i                           17.77431
# z                           16.66494
# run_ID                          2961
# rerun_ID                         301
# cam_col                            4
# field_ID                         102
# spec_obj_ID    1049505608023173248.0
# class                           STAR
# redshift                   -0.000011
# plate                            932
# MJD                            52620
# fiber_ID                         607
# Name: 96335, dtype: object
# Row:  obj_ID         1237659131671085568.0
# alpha                     214.038232
# delta                      50.722169
# u                           22.47456
# g                           21.79775
# r                           21.61338
# i                           21.50538
# z                           21.31688
# run_ID                          3180
# rerun_ID                         301
# cam_col                            2
# field_ID                          70
# spec_obj_ID    9464457954357170176.0
# class                           STAR
# redshift                   -0.000539
# plate                           8406
# MJD                            57513
# fiber_ID                         521
# Name: 4615, dtype: object
# Row:  obj_ID         1237670017272316416.0
# alpha                      44.878292
# delta                       6.864446
# u                            23.7044
# g                           21.51747
# r                           20.71376
# i                           20.31957
# z                           20.23585
# run_ID                          5714
# rerun_ID                         301
# cam_col                            6
# field_ID                         171
# spec_obj_ID    2614456194449827840.0
# class                           STAR
# redshift                   -0.000523
# plate                           2322
# MJD                            53727
# fiber_ID                         424
# Name: 47166, dtype: object
# Row:  obj_ID         1237655108365058304.0
# alpha                     136.309101
# delta                      48.974806
# u                           26.36182
# g                           21.29358
# r                           19.82976
# i                           18.91109
# z                            18.4925
# run_ID                          2243
# rerun_ID                         301
# cam_col                            4
# field_ID                         140
# spec_obj_ID    6457283181309876224.0
# class                         GALAXY
# redshift                    0.514076
# plate                           5735
# MJD                            55980
# fiber_ID                         899
# Name: 20798, dtype: object
# Row:  obj_ID          1237669701046698496.0
# alpha                        6.367718
# delta                        6.472839
# u                            23.02231
# g                            23.28752
# r                            21.67818
# i                            20.36957
# z                            19.65034
# run_ID                           5641
# rerun_ID                          301
# cam_col                             1
# field_ID                           39
# spec_obj_ID    12737409966203492352.0
# class                          GALAXY
# redshift                     0.741891
# plate                           11313
# MJD                             58426
# fiber_ID                          379
# Name: 72201, dtype: object
# Row:  obj_ID         1237667211041833472.0
# alpha                     125.461463
# delta                      16.062176
# u                           19.73224
# g                           18.13913
# r                             17.043
# i                           16.59754
# z                           16.23288
# run_ID                          5061
# rerun_ID                         301
# cam_col                            3
# field_ID                          76
# spec_obj_ID    2558170544721652224.0
# class                         GALAXY
# redshift                    0.153195
# plate                           2272
# MJD                            53713
# fiber_ID                         458
# Name: 10490, dtype: object
# Row:  obj_ID         1237661971719258368.0
# alpha                     177.661036
# delta                       7.490041
# u                           19.21274
# g                            18.2781
# r                           17.93814
# i                           17.80777
# z                           17.75628
# run_ID                          3841
# rerun_ID                         301
# cam_col                            4
# field_ID                          86
# spec_obj_ID    3654830609659960832.0
# class                           STAR
# redshift                    0.000031
# plate                           3246
# MJD                            54939
# fiber_ID                         580
# Name: 68380, dtype: object
# Row:  obj_ID         1237666338651112448.0
# alpha                      14.283898
# delta                      -0.597898
# u                            23.9875
# g                           21.98323
# r                           20.87238
# i                           20.76511
# z                           21.53372
# run_ID                          4858
# rerun_ID                         301
# cam_col                            2
# field_ID                         450
# spec_obj_ID    4757056390547396608.0
# class                         GALAXY
# redshift                    0.267969
# plate                           4225
# MJD                            55455
# fiber_ID                         470
# Name: 79652, dtype: object
# Image retrieval and saving complete.

# %% [markdown]
# # Generate Galaxy dataset

# %%
from tqdm.auto import tqdm
import pandas as pd

tqdm.pandas()

# Load the dataset
file_path = 'star_classification.csv'
df = pd.read_csv(file_path, encoding='ascii')

# Filter the dataset for GALAXY and No-GALAXY
qso_df = df[df['class'] == 'GALAXY'].sample(n=60, random_state=1)
no_qso_df = df[df['class'] != 'GALAXY'].sample(n=60, random_state=1)

# Check the number of entries for each class
count_qso = qso_df.shape[0]
count_no_qso = no_qso_df.shape[0]

print('Number of GALAXY entries:', count_qso)
print('Number of No-GALAXY entries:', count_no_qso)
# Out:
# Number of GALAXY entries: 60
# Number of No-GALAXY entries: 60

# %%
import os
import requests
from PIL import Image
from io import BytesIO

# Function to fetch the image from SDSS and save it
def fetch_sdss_image(row, image_type, save_dir):
    print("Row: ", row)
    # Construct the URL for the SDSS image cutout service
    url = 'http://skyserver.sdss.org/dr16/SkyServerWS/ImgCutout/getjpeg?ra=' + str(row['alpha']) + '&dec=' + str(row['delta']) + '&scale=0.2&width=64&height=64'
    response = requests.get(url)
    if response.status_code == 200:
        # Open the image and save it
        image = Image.open(BytesIO(response.content))
        obj_id = str(row['obj_ID'])
        image.save(os.path.join(save_dir, image_type + '_' + obj_id + '.jpg'))
    else:
        print('Failed to retrieve image for obj_ID ' + str(row['obj_ID']))

# Create directories for QSO and No-QSO images if they don't exist
galaxy_dir = 'galaxy_images'
no_galaxy_dir = 'no_galaxy_images'
os.makedirs(galaxy_dir, exist_ok=True)
os.makedirs(no_galaxy_dir, exist_ok=True)


no_qso_df.progress_apply(lambda row: fetch_sdss_image(row, 'No-GALAXY', no_galaxy_dir), axis=1)
# Fetch and save images for QSO


qso_df.progress_apply(lambda row: fetch_sdss_image(row, 'GALAXY', galaxy_dir), axis=1)
# Fetch and save images for No-QSO

print('Image retrieval and saving complete.')
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Row:  obj_ID         1237670457508101888.0
# alpha                      44.996697
# delta                       34.71337
# u                             17.985
# g                           16.33867
# r                           15.64343
# i                           15.35487
# z                           15.22151
# run_ID                          5817
# rerun_ID                         301
# cam_col                            2
# field_ID                         196
# spec_obj_ID    8167544392078611456.0
# class                           STAR
# redshift                   -0.000143
# plate                           7254
# MJD                            56625
# fiber_ID                         969
# Name: 34722, dtype: object
# Row:  obj_ID         1237678825172304640.0
# alpha                     327.705067
# delta                       4.172409
# u                           22.93113
# g                           21.97658
# r                            21.9972
# i                           21.80574
# z                           22.34481
# run_ID                          7765
# rerun_ID                         301
# cam_col                            4
# field_ID                         107
# spec_obj_ID    4606080250635639296.0
# class                           STAR
# redshift                    0.000337
# plate                           4091
# MJD                            55498
# fiber_ID                          86
# Name: 97507, dtype: object
# Row:  obj_ID         1237654381977862400.0
# alpha                     137.964993
# delta                      52.117551
# u                           20.98387
# g                           20.38655
# r                           19.62717
# i                            19.4798
# z                           19.38212
# run_ID                          2074
# rerun_ID                         301
# cam_col                            3
# field_ID                         127
# spec_obj_ID    8206767002444126208.0
# class                            QSO
# redshift                    1.340582
# plate                           7289
# MJD                            57039
# fiber_ID                         300
# Name: 58893, dtype: object
# Row:  obj_ID         1237680246813163520.0
# alpha                     357.027927
# delta                        20.2294
# u                           18.90497
# g                           17.77633
# r                            17.2846
# i                           17.08661
# z                           16.99478
# run_ID                          8096
# rerun_ID                         301
# cam_col                            4
# field_ID                         209
# spec_obj_ID    6897496855594424320.0
# class                           STAR
# redshift                   -0.001194
# plate                           6126
# MJD                            56269
# fiber_ID                         851
# Name: 40128, dtype: object
# Row:  obj_ID         1237660765372023296.0
# alpha                     124.303267
# delta                      26.794701
# u                           21.44086
# g                           20.22719
# r                           20.13715
# i                           20.08195
# z                           20.01783
# run_ID                          3560
# rerun_ID                         301
# cam_col                            5
# field_ID                         112
# spec_obj_ID    5022778671431440384.0
# class                           STAR
# redshift                    0.000556
# plate                           4461
# MJD                            55888
# fiber_ID                         506
# Name: 53529, dtype: object
# Row:  obj_ID         1237662224617308672.0
# alpha                     221.235577
# delta                      33.659197
# u                           25.76417
# g                            23.2412
# r                           21.80701
# i                           21.74759
# z                           22.26916
# run_ID                          3900
# rerun_ID                         301
# cam_col                            3
# field_ID                         572
# spec_obj_ID    4351610375223137792.0
# class                            QSO
# redshift                     3.88205
# plate                           3865
# MJD                            55272
# fiber_ID                          26
# Name: 87649, dtype: object
# Row:  obj_ID          1237667736104271872.0
# alpha                      147.879149
# delta                       18.995081
# u                            22.82579
# g                            22.35214
# r                            22.01644
# i                            21.81222
# z                            22.01068
# run_ID                           5183
# rerun_ID                          301
# cam_col                             5
# field_ID                          117
# spec_obj_ID    10748074288878000128.0
# class                             QSO
# redshift                     0.908904
# plate                            9546
# MJD                             57864
# fiber_ID                          850
# Name: 79439, dtype: object
# Row:  obj_ID         1237661959373193472.0
# alpha                     217.750422
# delta                      48.230722
# u                           20.60091
# g                           20.44582
# r                           20.76406
# i                           20.49894
# z                           20.46729
# run_ID                          3838
# rerun_ID                         301
# cam_col                            5
# field_ID                         116
# spec_obj_ID    9496041150500591616.0
# class                            QSO
# redshift                    1.921985
# plate                           8434
# MJD                            57484
# fiber_ID                         732
# Name: 68795, dtype: object
# Row:  obj_ID         1237678661427000064.0
# alpha                       6.849982
# delta                       4.648637
# u                           17.31973
# g                           16.42568
# r                           16.20041
# i                           16.12263
# z                           16.11765
# run_ID                          7727
# rerun_ID                         301
# cam_col                            3
# field_ID                         112
# spec_obj_ID    9848466236769587200.0
# class                           STAR
# redshift                    -0.00054
# plate                           8747
# MJD                            57401
# fiber_ID                         799
# Name: 48807, dtype: object
# Row:  obj_ID         1237665442593767424.0
# alpha                     206.093625
# delta                      28.945261
# u                           19.16638
# g                           18.78022
# r                           18.76328
# i                           18.56938
# z                           18.40818
# run_ID                          4649
# rerun_ID                         301
# cam_col                            5
# field_ID                         148
# spec_obj_ID    2271077884217026304.0
# class                            QSO
# redshift                    0.481624
# plate                           2017
# MJD                            53474
# fiber_ID                         501
# Name: 79780, dtype: object
# Row:  obj_ID         1237658204522349056.0
# alpha                     220.696378
# delta                      44.050925
# u                           22.28825
# g                           21.50239
# r                           20.71631
# i                           20.28263
# z                           19.92434
# run_ID                          2964
# rerun_ID                         301
# cam_col                            3
# field_ID                         487
# spec_obj_ID    9561260618373421056.0
# class                            QSO
# redshift                     1.41186
# plate                           8492
# MJD                            58171
# fiber_ID                         431
# Name: 65724, dtype: object
# Row:  obj_ID         1237662339474194688.0
# alpha                      236.00625
# delta                      28.834546
# u                           22.46527
# g                           21.84359
# r                           21.86079
# i                           21.79813
# z                           21.08537
# run_ID                          3927
# rerun_ID                         301
# cam_col                            1
# field_ID                          61
# spec_obj_ID    5321132797943109632.0
# class                            QSO
# redshift                    2.628266
# plate                           4726
# MJD                            55712
# fiber_ID                         472
# Name: 86225, dtype: object
# Row:  obj_ID         1237657589248491520.0
# alpha                     180.534977
# delta                      53.904267
# u                           20.42962
# g                           20.12276
# r                           20.11376
# i                           19.89267
# z                           19.86654
# run_ID                          2821
# rerun_ID                         301
# cam_col                            1
# field_ID                         185
# spec_obj_ID    9264157170836199424.0
# class                            QSO
# redshift                    1.604187
# plate                           8228
# MJD                            57423
# fiber_ID                         919
# Name: 56222, dtype: object
# Row:  obj_ID         1237655693014925312.0
# alpha                     224.269331
# delta                      -1.381415
# u                           18.95602
# g                             18.602
# r                           18.68396
# i                           18.54616
# z                           18.53831
# run_ID                          2379
# rerun_ID                         301
# cam_col                            5
# field_ID                         101
# spec_obj_ID    1037094041864398848.0
# class                            QSO
# redshift                    0.524981
# plate                            921
# MJD                            52380
# fiber_ID                         510
# Name: 31123, dtype: object
# Row:  obj_ID         1237668350820155648.0
# alpha                     214.718238
# delta                      16.243387
# u                           20.08897
# g                           19.81443
# r                           19.74142
# i                            19.6001
# z                           19.28599
# run_ID                          5326
# rerun_ID                         301
# cam_col                            6
# field_ID                          97
# spec_obj_ID    3091824294406154240.0
# class                            QSO
# redshift                      0.7021
# plate                           2746
# MJD                            54232
# fiber_ID                         375
# Name: 73621, dtype: object
# Row:  obj_ID         1237659327093342208.0
# alpha                     223.203252
# delta                      55.076937
# u                           24.50067
# g                           18.82895
# r                           25.60661
# i                           16.61457
# z                           23.22743
# run_ID                          3225
# rerun_ID                         301
# cam_col                            6
# field_ID                          89
# spec_obj_ID    9466764460930914304.0
# class                           STAR
# redshift                   -0.000045
# plate                           8408
# MJD                            57874
# fiber_ID                         720
# Name: 41897, dtype: object
# Row:  obj_ID         1237658303276974336.0
# alpha                     152.815573
# delta                      55.466308
# u                           22.82479
# g                           21.81788
# r                           21.01184
# i                           20.72953
# z                           20.36031
# run_ID                          2987
# rerun_ID                         301
# cam_col                            3
# field_ID                          35
# spec_obj_ID    7976110896450918400.0
# class                            QSO
# redshift                    2.622228
# plate                           7084
# MJD                            56624
# fiber_ID                         858
# Name: 55715, dtype: object
# Row:  obj_ID         1237646796522522624.0
# alpha                     111.077075
# delta                      -0.325197
# u                            21.2362
# g                            18.9031
# r                           17.73198
# i                           17.23954
# z                            16.9735
# run_ID                           308
# rerun_ID                         301
# cam_col                            2
# field_ID                          32
# spec_obj_ID    8387978333133232128.0
# class                           STAR
# redshift                    0.000095
# plate                           7450
# MJD                            56722
# fiber_ID                          87
# Name: 16230, dtype: object
# Row:  obj_ID         1237654380908708096.0
# alpha                     153.774553
# delta                      57.460152
# u                           20.58047
# g                           20.47692
# r                           20.16945
# i                           20.25602
# z                           19.84869
# run_ID                          2074
# rerun_ID                         301
# cam_col                            1
# field_ID                         197
# spec_obj_ID    9217991701242860544.0
# class                            QSO
# redshift                    0.988306
# plate                           8187
# MJD                            57423
# fiber_ID                         906
# Name: 40096, dtype: object
# Row:  obj_ID         1237655504570023936.0
# alpha                     254.789546
# delta                      38.723477
# u                           17.99958
# g                           16.26862
# r                           15.59345
# i                           15.33927
# z                           15.23079
# run_ID                          2335
# rerun_ID                         301
# cam_col                            6
# field_ID                          52
# spec_obj_ID    2455652352254830592.0
# class                           STAR
# redshift                   -0.000022
# plate                           2181
# MJD                            53524
# fiber_ID                         235
# Name: 25384, dtype: object
# Row:  obj_ID         1237655504569238016.0
# alpha                     253.689128
# delta                      40.187016
# u                           19.61693
# g                           18.25824
# r                            17.7554
# i                           17.57476
# z                           17.47527
# run_ID                          2335
# rerun_ID                         301
# cam_col                            6
# field_ID                          40
# spec_obj_ID    2468078219916503040.0
# class                           STAR
# redshift                   -0.000012
# plate                           2192
# MJD                            54232
# fiber_ID                         384
# Name: 88950, dtype: object
# Row:  obj_ID         1237680299427234304.0
# alpha                     356.428747
# delta                      23.138398
# u                           22.23057
# g                           22.17575
# r                           21.85174
# i                           21.93592
# z                           21.44052
# run_ID                          8108
# rerun_ID                         301
# cam_col                            6
# field_ID                         220
# spec_obj_ID    8557081851491276800.0
# class                            QSO
# redshift                    1.444657
# plate                           7600
# MJD                            56984
# fiber_ID                         882
# Name: 98595, dtype: object
# Row:  obj_ID         1237661137959125248.0
# alpha                      151.42216
# delta                      37.183916
# u                            19.3639
# g                           18.96955
# r                           18.97849
# i                           19.11656
# z                           19.26493
# run_ID                          3647
# rerun_ID                         301
# cam_col                            3
# field_ID                          92
# spec_obj_ID    9968971062728480768.0
# class                           STAR
# redshift                    0.000107
# plate                           8854
# MJD                            57450
# fiber_ID                         921
# Name: 83230, dtype: object
# Row:  obj_ID         1237678618505314816.0
# alpha                      31.347073
# delta                       1.909884
# u                           22.62224
# g                           22.29546
# r                           21.95896
# i                           21.68433
# z                           20.97102
# run_ID                          7717
# rerun_ID                         301
# cam_col                            3
# field_ID                         539
# spec_obj_ID    8819283768823273472.0
# class                            QSO
# redshift                    1.989826
# plate                           7833
# MJD                            57286
# fiber_ID                         399
# Name: 28149, dtype: object
# Row:  obj_ID         1237665025441136896.0
# alpha                      182.70493
# delta                      35.255827
# u                            20.7299
# g                            20.3198
# r                           20.30556
# i                           20.03767
# z                           20.00944
# run_ID                          4552
# rerun_ID                         301
# cam_col                            4
# field_ID                          88
# spec_obj_ID    2352161369610020864.0
# class                            QSO
# redshift                    0.621764
# plate                           2089
# MJD                            53498
# fiber_ID                         569
# Name: 24678, dtype: object
# Row:  obj_ID         1237658492259205120.0
# alpha                      133.63576
# delta                       5.920295
# u                           19.56137
# g                           18.71244
# r                            18.3222
# i                           18.18334
# z                           18.09478
# run_ID                          3031
# rerun_ID                         301
# cam_col                            3
# field_ID                          91
# spec_obj_ID    5479787381585631232.0
# class                           STAR
# redshift                   -0.000173
# plate                           4867
# MJD                            55924
# fiber_ID                         118
# Name: 63317, dtype: object
# Row:  obj_ID         1237679254671392768.0
# alpha                      34.211943
# delta                      -4.127113
# u                           20.90846
# g                           18.94314
# r                           18.42417
# i                           18.22682
# z                           18.10205
# run_ID                          7865
# rerun_ID                         301
# cam_col                            4
# field_ID                         143
# spec_obj_ID    4942754292023187456.0
# class                           STAR
# redshift                   -0.000015
# plate                           4390
# MJD                            55948
# fiber_ID                         195
# Name: 20277, dtype: object
# Row:  obj_ID         1237654879130091520.0
# alpha                     223.357597
# delta                       2.874377
# u                           19.35462
# g                           18.24072
# r                           17.91047
# i                            17.7725
# z                            17.7099
# run_ID                          2190
# rerun_ID                         301
# cam_col                            1
# field_ID                         276
# spec_obj_ID     662064363904985088.0
# class                           STAR
# redshift                     0.00037
# plate                            588
# MJD                            52045
# fiber_ID                         128
# Name: 17903, dtype: object
# Row:  obj_ID          1237659154217631488.0
# alpha                      246.056717
# delta                        35.20293
# u                             22.4575
# g                            21.56331
# r                            21.12707
# i                             21.0063
# z                            21.27385
# run_ID                           3185
# rerun_ID                          301
# cam_col                             4
# field_ID                           39
# spec_obj_ID    12283722878395111424.0
# class                            STAR
# redshift                     -0.00024
# plate                           10910
# MJD                             58254
# fiber_ID                          563
# Name: 11035, dtype: object
# Row:  obj_ID         1237661976011210752.0
# alpha                      187.00401
# delta                       7.912611
# u                           18.18704
# g                           17.20247
# r                           16.91394
# i                           16.79438
# z                           16.79927
# run_ID                          3842
# rerun_ID                         301
# cam_col                            4
# field_ID                          40
# spec_obj_ID    1831945309572327680.0
# class                           STAR
# redshift                    0.000302
# plate                           1627
# MJD                            53473
# fiber_ID                         386
# Name: 3511, dtype: object
# Row:  obj_ID         1237652944231006720.0
# alpha                     317.842258
# delta                      10.966343
# u                            19.4833
# g                           16.88873
# r                           15.51406
# i                           14.52995
# z                           14.00949
# run_ID                          1739
# rerun_ID                         301
# cam_col                            5
# field_ID                          27
# spec_obj_ID    2128045985996236800.0
# class                           STAR
# redshift                   -0.000237
# plate                           1890
# MJD                            53237
# fiber_ID                         346
# Name: 52913, dtype: object
# Row:  obj_ID         1237658204511535104.0
# alpha                      185.02418
# delta                      49.861938
# u                           19.38981
# g                           18.33172
# r                           17.97042
# i                           17.84137
# z                           17.79215
# run_ID                          2964
# rerun_ID                         301
# cam_col                            3
# field_ID                         322
# spec_obj_ID    1092154561080092544.0
# class                           STAR
# redshift                   -0.000098
# plate                            970
# MJD                            52413
# fiber_ID                         115
# Name: 26632, dtype: object
# Row:  obj_ID          1237673706650862336.0
# alpha                      111.596206
# delta                       41.418921
# u                            24.67739
# g                            23.08862
# r                            21.55337
# i                            20.40165
# z                            19.71258
# run_ID                           6573
# rerun_ID                          301
# cam_col                             6
# field_ID                          196
# spec_obj_ID    11997698670797803520.0
# class                            STAR
# redshift                     0.000177
# plate                           10656
# MJD                             58163
# fiber_ID                          397
# Name: 49003, dtype: object
# Row:  obj_ID         1237679457612988672.0
# alpha                       8.492097
# delta                      18.467922
# u                           21.09587
# g                           20.60048
# r                           20.44908
# i                           20.19127
# z                           20.16367
# run_ID                          7912
# rerun_ID                         301
# cam_col                            6
# field_ID                         210
# spec_obj_ID    8543436086197901312.0
# class                            QSO
# redshift                    1.684059
# plate                           7588
# MJD                            56903
# fiber_ID                         391
# Name: 12564, dtype: object
# Row:  obj_ID         1237663462607618304.0
# alpha                     351.552941
# delta                       0.672028
# u                           23.94065
# g                           21.16703
# r                            19.7659
# i                           18.92519
# z                           18.50456
# run_ID                          4188
# rerun_ID                         301
# cam_col                            5
# field_ID                          53
# spec_obj_ID    1233010798503159808.0
# class                           STAR
# redshift                   -0.000328
# plate                           1095
# MJD                            52521
# fiber_ID                         547
# Name: 77896, dtype: object
# Row:  obj_ID         1237680276873806080.0
# alpha                       8.474148
# delta                      27.587912
# u                           19.54165
# g                           19.10828
# r                            18.7593
# i                           18.54578
# z                           18.40383
# run_ID                          8103
# rerun_ID                         301
# cam_col                            4
# field_ID                         146
# spec_obj_ID    7073106734697699328.0
# class                            QSO
# redshift                    2.109774
# plate                           6282
# MJD                            56572
# fiber_ID                         740
# Name: 69542, dtype: object
# Row:  obj_ID         1237662335726059520.0
# alpha                     254.536493
# delta                      19.846714
# u                           20.56102
# g                           18.85056
# r                           18.53157
# i                           18.39353
# z                           18.78069
# run_ID                          3926
# rerun_ID                         301
# cam_col                            2
# field_ID                         213
# spec_obj_ID    4700726214608049152.0
# class                           STAR
# redshift                   -0.000654
# plate                           4175
# MJD                            55680
# fiber_ID                         342
# Name: 21270, dtype: object
# Row:  obj_ID         1237659326033428736.0
# alpha                     254.246433
# delta                      32.244119
# u                           19.18958
# g                           19.04362
# r                            18.8395
# i                           18.68002
# z                           18.73989
# run_ID                          3225
# rerun_ID                         301
# cam_col                            4
# field_ID                         300
# spec_obj_ID    1324209794998888448.0
# class                            QSO
# redshift                    1.458923
# plate                           1176
# MJD                            52791
# fiber_ID                         551
# Name: 45170, dtype: object
# Row:  obj_ID         1237679254672244736.0
# alpha                      36.138173
# delta                      -4.008533
# u                           23.20743
# g                           22.45728
# r                           21.98594
# i                           21.82488
# z                           21.06215
# run_ID                          7865
# rerun_ID                         301
# cam_col                            4
# field_ID                         156
# spec_obj_ID    7171080911358023680.0
# class                            QSO
# redshift                    1.389511
# plate                           6369
# MJD                            56217
# fiber_ID                         816
# Name: 20635, dtype: object
# Row:  obj_ID          1237678597555879936.0
# alpha                        5.237298
# delta                        2.739343
# u                            17.77839
# g                            16.79123
# r                             16.5149
# i                            16.37613
# z                            16.32488
# run_ID                           7712
# rerun_ID                          301
# cam_col                             4
# field_ID                          364
# spec_obj_ID    10628496355533000704.0
# class                            STAR
# redshift                     -0.00026
# plate                            9440
# MJD                             58072
# fiber_ID                            4
# Name: 34780, dtype: object
# Row:  obj_ID         1237658187315347968.0
# alpha                      85.912058
# delta                       -0.27929
# u                           22.00648
# g                           19.43146
# r                           17.96695
# i                           16.78568
# z                            16.1346
# run_ID                          2960
# rerun_ID                         301
# cam_col                            3
# field_ID                          73
# spec_obj_ID    1402990930943830016.0
# class                           STAR
# redshift                   -0.000014
# plate                           1246
# MJD                            54478
# fiber_ID                         435
# Name: 10444, dtype: object
# Row:  obj_ID          1237678859019288832.0
# alpha                       25.170558
# delta                       11.657323
# u                             21.0143
# g                            20.85163
# r                            20.52154
# i                            20.34998
# z                            20.49078
# run_ID                           7773
# rerun_ID                          301
# cam_col                             3
# field_ID                          475
# spec_obj_ID    12453655152166195200.0
# class                             QSO
# redshift                     1.419346
# plate                           11061
# MJD                             58428
# fiber_ID                          277
# Name: 48091, dtype: object
# Row:  obj_ID         1237657190914457600.0
# alpha                      21.071127
# delta                      -0.202993
# u                           20.24568
# g                           20.06705
# r                           19.82747
# i                           19.75182
# z                           19.74858
# run_ID                          2728
# rerun_ID                         301
# cam_col                            3
# field_ID                         554
# spec_obj_ID    1215982663484073984.0
# class                            QSO
# redshift                    1.311673
# plate                           1080
# MJD                            52614
# fiber_ID                          39
# Name: 54956, dtype: object
# Row:  obj_ID         1237659131670561024.0
# alpha                     212.218124
# delta                      51.128399
# u                            21.3627
# g                            20.4029
# r                           20.26917
# i                           20.13431
# z                           19.97265
# run_ID                          3180
# rerun_ID                         301
# cam_col                            2
# field_ID                          62
# spec_obj_ID    7589700725149817856.0
# class                            QSO
# redshift                    2.729483
# plate                           6741
# MJD                            56394
# fiber_ID                          34
# Name: 4120, dtype: object
# Row:  obj_ID         1237678596459332352.0
# alpha                     313.134423
# delta                        0.95207
# u                           21.18992
# g                           19.04718
# r                           17.80346
# i                           17.36594
# z                            17.0315
# run_ID                          7712
# rerun_ID                         301
# cam_col                            2
# field_ID                          16
# spec_obj_ID    1106873173988632448.0
# class                           STAR
# redshift                   -0.000098
# plate                            983
# MJD                            52443
# fiber_ID                         413
# Name: 28236, dtype: object
# Row:  obj_ID         1237662267531133184.0
# alpha                     214.032471
# delta                       6.413656
# u                           20.00974
# g                           18.78677
# r                           18.71602
# i                           18.73362
# z                           18.74274
# run_ID                          3910
# rerun_ID                         301
# cam_col                            3
# field_ID                          25
# spec_obj_ID    2054924618937952000.0
# class                           STAR
# redshift                     -0.0002
# plate                           1825
# MJD                            53504
# fiber_ID                         572
# Name: 96123, dtype: object
# Row:  obj_ID         1237653665257881856.0
# alpha                     147.806525
# delta                        2.40224
# u                           20.36977
# g                             19.054
# r                           18.59802
# i                           18.71005
# z                           18.37234
# run_ID                          1907
# rerun_ID                         301
# cam_col                            4
# field_ID                         168
# spec_obj_ID     541685980306892800.0
# class                           STAR
# redshift                    0.000208
# plate                            481
# MJD                            51908
# fiber_ID                         466
# Name: 70457, dtype: object
# Row:  obj_ID         1237661361835409664.0
# alpha                     203.967583
# delta                      45.929334
# u                            23.8611
# g                           20.71846
# r                           20.03971
# i                           19.79435
# z                           19.58279
# run_ID                          3699
# rerun_ID                         301
# cam_col                            4
# field_ID                         109
# spec_obj_ID    7597651843100203008.0
# class                           STAR
# redshift                   -0.000017
# plate                           6748
# MJD                            56371
# fiber_ID                         288
# Name: 43083, dtype: object
# Row:  obj_ID         1237662303505154304.0
# alpha                     203.539598
# delta                      52.307889
# u                           20.75668
# g                           20.49485
# r                           20.38645
# i                           20.05152
# z                           19.71211
# run_ID                          3918
# rerun_ID                         301
# cam_col                            6
# field_ID                          81
# spec_obj_ID    9241463525834250240.0
# class                            QSO
# redshift                    0.487246
# plate                           8208
# MJD                            57430
# fiber_ID                         280
# Name: 77327, dtype: object
# Row:  obj_ID         1237662301355376896.0
# alpha                     194.597491
# delta                      51.508443
# u                           22.40355
# g                           21.91987
# r                           21.86446
# i                           21.68258
# z                           21.38954
# run_ID                          3918
# rerun_ID                         301
# cam_col                            2
# field_ID                          46
# spec_obj_ID    9257178295791017984.0
# class                            QSO
# redshift                     2.51333
# plate                           8222
# MJD                            57431
# fiber_ID                         106
# Name: 91130, dtype: object
# Row:  obj_ID          1237662337324810496.0
# alpha                      231.057383
# delta                       37.700812
# u                            20.38034
# g                            19.98515
# r                            19.83652
# i                            19.50817
# z                            19.30039
# run_ID                           3926
# rerun_ID                          301
# cam_col                             5
# field_ID                           32
# spec_obj_ID    12095546135688796160.0
# class                             QSO
# redshift                     0.572928
# plate                           10743
# MJD                             58222
# fiber_ID                           12
# Name: 82262, dtype: object
# Row:  obj_ID         1237660772884873472.0
# alpha                     157.010723
# delta                      41.090441
# u                           22.13685
# g                           21.80162
# r                           21.63638
# i                           21.44284
# z                           21.34773
# run_ID                          3562
# rerun_ID                         301
# cam_col                            3
# field_ID                          61
# spec_obj_ID    9415928820161335296.0
# class                            QSO
# redshift                    1.927722
# plate                           8363
# MJD                            58140
# fiber_ID                         101
# Name: 76629, dtype: object
# Row:  obj_ID         1237658206122344448.0
# alpha                     185.720171
# delta                       51.17074
# u                           17.77518
# g                            16.7915
# r                           16.49994
# i                           16.39262
# z                           16.36744
# run_ID                          2964
# rerun_ID                         301
# cam_col                            6
# field_ID                         325
# spec_obj_ID    9262918296176711680.0
# class                           STAR
# redshift                   -0.000608
# plate                           8227
# MJD                            57427
# fiber_ID                         508
# Name: 19379, dtype: object
# Row:  obj_ID         1237662302442422272.0
# alpha                      235.70595
# delta                      39.884734
# u                           21.12258
# g                           21.01942
# r                           20.93306
# i                           20.93195
# z                            21.3193
# run_ID                          3918
# rerun_ID                         301
# cam_col                            4
# field_ID                         249
# spec_obj_ID    9584906984798574592.0
# class                            QSO
# redshift                    1.413698
# plate                           8513
# MJD                            57842
# fiber_ID                         440
# Name: 86602, dtype: object
# Row:  obj_ID         1237670965393096704.0
# alpha                     157.620276
# delta                       18.11466
# u                           24.26113
# g                           20.09637
# r                           19.47975
# i                           18.99124
# z                           21.12099
# run_ID                          5935
# rerun_ID                         301
# cam_col                            4
# field_ID                         274
# spec_obj_ID    3229243460343064576.0
# class                           STAR
# redshift                    0.000271
# plate                           2868
# MJD                            54451
# fiber_ID                         591
# Name: 9468, dtype: object
# Row:  obj_ID         1237660240312664320.0
# alpha                      47.727912
# delta                      -0.283115
# u                           19.32334
# g                           17.70436
# r                           17.09547
# i                           16.88155
# z                           16.77701
# run_ID                          3438
# rerun_ID                         301
# cam_col                            3
# field_ID                         118
# spec_obj_ID    8168433621637814272.0
# class                           STAR
# redshift                   -0.000119
# plate                           7255
# MJD                            56597
# fiber_ID                         108
# Name: 71739, dtype: object
# Row:  obj_ID         1237651065204507136.0
# alpha                     178.638291
# delta                      63.825522
# u                           22.20827
# g                           21.35176
# r                           20.77312
# i                           20.05197
# z                           19.67334
# run_ID                          1302
# rerun_ID                         301
# cam_col                            1
# field_ID                         358
# spec_obj_ID    8000859529456930816.0
# class                            QSO
# redshift                    0.559366
# plate                           7106
# MJD                            56663
# fiber_ID                         781
# Name: 34997, dtype: object
# Row:  obj_ID         1237663462608404736.0
# alpha                     353.271408
# delta                       0.706646
# u                           21.12152
# g                           20.77399
# r                           20.47561
# i                           20.61573
# z                           20.37193
# run_ID                          4188
# rerun_ID                         301
# cam_col                            5
# field_ID                          65
# spec_obj_ID    1673212656107939840.0
# class                            QSO
# redshift                    1.007655
# plate                           1486
# MJD                            52993
# fiber_ID                         456
# Name: 19734, dtype: object
# Row:  obj_ID         1237663789022904320.0
# alpha                     109.345862
# delta                      39.852436
# u                           19.46342
# g                           18.42369
# r                           18.31182
# i                           18.19953
# z                           18.15644
# run_ID                          4264
# rerun_ID                         301
# cam_col                            5
# field_ID                          19
# spec_obj_ID    3608557936156188672.0
# class                           STAR
# redshift                   -0.000145
# plate                           3205
# MJD                            54848
# fiber_ID                         177
# Name: 37650, dtype: object
# Row:  obj_ID         1237654948913479936.0
# alpha                     238.999327
# delta                      54.430275
# u                           21.13959
# g                           20.56803
# r                           20.51416
# i                           20.10295
# z                           19.84846
# run_ID                          2206
# rerun_ID                         301
# cam_col                            3
# field_ID                         126
# spec_obj_ID    9472301601874270208.0
# class                            QSO
# redshift                    0.609372
# plate                           8413
# MJD                            57897
# fiber_ID                         384
# Name: 73354, dtype: object
#   0%|          | 0/60 [00:00<?, ?it/s]
# Row:  obj_ID         1237659324948480512.0
# alpha                     229.567766
# delta                      50.255307
# u                           24.57674
# g                           22.47833
# r                           20.52957
# i                           19.57433
# z                           19.05979
# run_ID                          3225
# rerun_ID                         301
# cam_col                            2
# field_ID                         129
# spec_obj_ID    7574076664499689472.0
# class                         GALAXY
# redshift                         0.0
# plate                           6727
# MJD                            56369
# fiber_ID                         538
# Name: 68459, dtype: object
# Row:  obj_ID         1237663916266554112.0
# alpha                     121.285066
# delta                       53.30715
# u                           22.37352
# g                           23.45388
# r                           21.67516
# i                           20.63716
# z                           19.90065
# run_ID                          4294
# rerun_ID                         301
# cam_col                            2
# field_ID                          99
# spec_obj_ID    8219259922866787328.0
# class                         GALAXY
# redshift                     0.58525
# plate                           7300
# MJD                            56707
# fiber_ID                         693
# Name: 67463, dtype: object
# Row:  obj_ID         1237678617405817088.0
# alpha                     332.506961
# delta                       0.952897
# u                           20.80461
# g                           20.38059
# r                           20.03865
# i                           19.96852
# z                           19.45564
# run_ID                          7717
# rerun_ID                         301
# cam_col                            1
# field_ID                         146
# spec_obj_ID    1244287121859045120.0
# class                         GALAXY
# redshift                    0.779411
# plate                           1105
# MJD                            52937
# fiber_ID                         610
# Name: 99887, dtype: object
# Row:  obj_ID         1237661212045082880.0
# alpha                     218.809475
# delta                      45.280258
# u                           23.25497
# g                           20.84206
# r                           19.02691
# i                           18.23119
# z                           17.80348
# run_ID                          3664
# rerun_ID                         301
# cam_col                            5
# field_ID                          58
# spec_obj_ID    1450294090884212736.0
# class                         GALAXY
# redshift                    0.458134
# plate                           1288
# MJD                            52731
# fiber_ID                         491
# Name: 89152, dtype: object
# Row:  obj_ID         1237648720695919104.0
# alpha                     184.755997
# delta                      -0.435148
# u                           22.99235
# g                           21.48464
# r                           19.75202
# i                           18.85002
# z                           18.39786
# run_ID                           756
# rerun_ID                         301
# cam_col                            2
# field_ID                         460
# spec_obj_ID     324309234504198144.0
# class                         GALAXY
# redshift                    0.474882
# plate                            288
# MJD                            52000
# fiber_ID                         182
# Name: 22073, dtype: object
# Row:  obj_ID         1237679255208263936.0
# alpha                      34.218974
# delta                      -3.546551
# u                           23.03234
# g                           20.17648
# r                           18.61415
# i                           18.05697
# z                           17.66058
# run_ID                          7865
# rerun_ID                         301
# cam_col                            5
# field_ID                         143
# spec_obj_ID    4942931588273166336.0
# class                         GALAXY
# redshift                    0.326113
# plate                           4390
# MJD                            55948
# fiber_ID                         840
# Name: 64985, dtype: object
# Row:  obj_ID         1237664853109244416.0
# alpha                     220.350822
# delta                       31.94841
# u                            22.0347
# g                           21.32819
# r                            20.6039
# i                           19.74233
# z                           19.39916
# run_ID                          4512
# rerun_ID                         301
# cam_col                            3
# field_ID                         144
# spec_obj_ID    4355226395565381632.0
# class                         GALAXY
# redshift                    0.706793
# plate                           3868
# MJD                            55360
# fiber_ID                         893
# Name: 4498, dtype: object
# Row:  obj_ID         1237678597544281088.0
# alpha                     338.701854
# delta                       2.517357
# u                            24.1206
# g                           22.98149
# r                            20.7404
# i                           19.74313
# z                           19.35603
# run_ID                          7712
# rerun_ID                         301
# cam_col                            4
# field_ID                         187
# spec_obj_ID    4867497667830504448.0
# class                         GALAXY
# redshift                    0.538324
# plate                           4323
# MJD                            55884
# fiber_ID                         845
# Name: 90615, dtype: object
# Row:  obj_ID         1237658302742266880.0
# alpha                     161.219112
# delta                      57.283817
# u                           22.55869
# g                           25.70659
# r                           21.27297
# i                            20.1322
# ...
# r                           21.76929
# i                            20.6253
# z                           19.94031
# run_ID                          3650
# rerun_ID                         301
# cam_col                            4
# field_ID                         126
# spec_obj_ID    9569099024352696320.0
# class                         GALAXY
# redshift                     0.61229
# plate                           8499
# MJD                            57431
# fiber_ID                         275
# Name: 99816, dtype: object
# Row:  obj_ID         1237648721788403968.0
# alpha                     227.568629
# delta                       0.398666
# u                           19.15206
# g                           18.20064
# r                           17.76346
# i                           17.42592
# z                           17.35575
# run_ID                           756
# rerun_ID                         301
# cam_col                            4
# field_ID                         746
# spec_obj_ID     350271722072598464.0
# class                         GALAXY
# redshift                     0.10485
# plate                            311
# MJD                            51665
# fiber_ID                         425
# Name: 61095, dtype: object
# Row:  obj_ID         1237650371545137664.0
# alpha                     155.914175
# delta                      -1.353322
# u                           21.92004
# g                           21.58001
# r                           21.07425
# i                           20.23524
# z                           19.83854
# run_ID                          1140
# rerun_ID                         301
# cam_col                            5
# field_ID                          20
# spec_obj_ID    4244840373825067008.0
# class                         GALAXY
# redshift                    0.702705
# plate                           3770
# MJD                            55234
# fiber_ID                         719
# Name: 61652, dtype: object
# Row:  obj_ID         1237679433986605568.0
# alpha                      11.437938
# delta                      -3.297772
# u                           25.82551
# g                           22.40442
# r                           21.15077
# i                           20.04218
# z                           19.55229
# run_ID                          7907
# rerun_ID                         301
# cam_col                            2
# field_ID                         148
# spec_obj_ID    4920260476196378624.0
# class                         GALAXY
# redshift                    0.576982
# plate                           4370
# MJD                            55534
# fiber_ID                         283
# Name: 98917, dtype: object
# Row:  obj_ID         1237678661423530752.0
# alpha                     358.885334
# delta                       4.564813
# u                           26.26539
# g                           23.32694
# r                           21.61087
# i                           20.37859
# z                           19.72651
# run_ID                          7727
# rerun_ID                         301
# cam_col                            3
# field_ID                          59
# spec_obj_ID    9842630028428595200.0
# class                         GALAXY
# redshift                    0.710211
# plate                           8742
# MJD                            57364
# fiber_ID                          47
# Name: 94190, dtype: object
# Row:  obj_ID          1237660962937438720.0
# alpha                      132.871751
# delta                        32.30614
# u                            22.51507
# g                            21.49694
# r                            21.15487
# i                            20.87926
# z                            20.86734
# run_ID                           3606
# rerun_ID                          301
# cam_col                             5
# field_ID                           65
# spec_obj_ID    11526969430388267008.0
# class                          GALAXY
# redshift                          0.0
# plate                           10238
# MJD                             58155
# fiber_ID                           22
# Name: 67637, dtype: object
# Row:  obj_ID         1237680264538947840.0
# alpha                       4.111047
# delta                      -6.779052
# u                           22.36347
# g                           22.38787
# r                           20.46143
# i                            19.5824
# z                           19.27968
# run_ID                          8100
# rerun_ID                         301
# cam_col                            5
# field_ID                         347
# spec_obj_ID    8049323252055824384.0
# class                         GALAXY
# redshift                    0.435252
# plate                           7149
# MJD                            56593
# fiber_ID                         963
# Name: 61068, dtype: object
# Row:  obj_ID         1237680246813229568.0
# alpha                     357.135649
# delta                      20.232108
# u                            23.1323
# g                           21.67029
# r                           19.74356
# i                           19.02727
# z                           18.37116
# run_ID                          8096
# rerun_ID                         301
# cam_col                            4
# field_ID                         210
# spec_obj_ID    6897508675344422912.0
# class                         GALAXY
# redshift                    0.400166
# plate                           6126
# MJD                            56269
# fiber_ID                         894
# Name: 2153, dtype: object
# Row:  obj_ID         1237651737386483968.0
# alpha                     223.246947
# delta                       2.623361
# u                           19.05457
# g                           17.42661
# r                           16.56527
# i                           16.11977
# z                           15.79034
# run_ID                          1458
# rerun_ID                         301
# cam_col                            5
# field_ID                         657
# spec_obj_ID     605847983375804416.0
# class                         GALAXY
# redshift                    0.083404
# plate                            538
# MJD                            52029
# fiber_ID                         414
# Name: 2432, dtype: object
# Row:  obj_ID          1237679255208591872.0
# alpha                       35.019064
# delta                          -3.701
# u                             23.5258
# g                            23.89886
# r                            21.45044
# i                            21.11762
# z                            21.38567
# run_ID                           7865
# rerun_ID                          301
# cam_col                             5
# field_ID                          148
# spec_obj_ID    10497009332960647168.0
# class                          GALAXY
# redshift                     0.843321
# plate                            9323
# MJD                             58047
# fiber_ID                          889
# Name: 74572, dtype: object
# Row:  obj_ID         1237651540314882304.0
# alpha                     142.831553
# delta                      62.201016
# u                           20.56544
# g                           18.52085
# r                           17.48058
# i                           17.07172
# z                           16.71352
# run_ID                          1412
# rerun_ID                         301
# cam_col                            6
# field_ID                          47
# spec_obj_ID    2011986232095041280.0
# class                         GALAXY
# redshift                    0.131034
# plate                           1787
# MJD                            54465
# fiber_ID                          11
# Name: 23404, dtype: object
# Row:  obj_ID         1237661150301913856.0
# alpha                     185.718787
# delta                      49.225723
# u                            23.7002
# g                            23.7739
# r                            22.1816
# i                           20.75157
# z                           19.93965
# run_ID                          3650
# rerun_ID                         301
# cam_col                            2
# field_ID                          12
# spec_obj_ID    8352059494709352448.0
# class                         GALAXY
# redshift                     0.60065
# plate                           7418
# MJD                            57165
# fiber_ID                         487
# Name: 95435, dtype: object
# Row:  obj_ID         1237661137958469632.0
# alpha                     149.580233
# delta                      36.747555
# u                           19.80306
# g                           18.32657
# r                           17.51701
# i                           17.12973
# z                           16.85791
# run_ID                          3647
# rerun_ID                         301
# cam_col                            3
# field_ID                          82
# spec_obj_ID    1796983855496849408.0
# class                         GALAXY
# redshift                    0.091754
# plate                           1596
# MJD                            52998
# fiber_ID                         173
# Name: 28538, dtype: object
# Row:  obj_ID         1237660962943598848.0
# alpha                     147.863214
# delta                      39.415526
# u                           22.30498
# g                            19.6944
# r                           18.14106
# i                           17.59987
# z                           17.21153
# run_ID                          3606
# rerun_ID                         301
# cam_col                            5
# field_ID                         159
# spec_obj_ID    5219741337096837120.0
# class                         GALAXY
# redshift                    0.284502
# plate                           4636
# MJD                            55945
# fiber_ID                         252
# Name: 53095, dtype: object
# Row:  obj_ID          1237668495773598720.0
# alpha                      156.299168
# delta                       15.630283
# u                            26.69464
# g                            22.52109
# r                            21.75553
# i                            20.80362
# z                            20.88076
# run_ID                           5360
# rerun_ID                          301
# cam_col                             4
# field_ID                           71
# spec_obj_ID    10781656122769299456.0
# class                          GALAXY
# redshift                     0.937452
# plate                            9576
# MJD                             57864
# fiber_ID                          140
# Name: 70939, dtype: object
# Row:  obj_ID         1237655126087434240.0
# alpha                     194.702499
# delta                       5.368539
# u                           19.14731
# g                           17.86716
# r                           17.39001
# i                           17.11095
# z                           16.98415
# run_ID                          2247
# rerun_ID                         301
# cam_col                            5
# field_ID                         226
# spec_obj_ID     954914623507687424.0
# class                         GALAXY
# redshift                    0.042002
# plate                            848
# MJD                            52669
# fiber_ID                         551
# Name: 64480, dtype: object
# Row:  obj_ID         1237659327093735936.0
# alpha                     224.547485
# delta                      54.597708
# u                           23.24878
# g                           23.95381
# r                           21.51083
# i                            20.4548
# z                           19.57632
# run_ID                          3225
# rerun_ID                         301
# cam_col                            6
# field_ID                          95
# spec_obj_ID    9466594861262329856.0
# class                         GALAXY
# redshift                    0.813283
# plate                           8408
# MJD                            57874
# fiber_ID                         103
# Name: 69947, dtype: object
# Row:  obj_ID         1237668296600060672.0
# alpha                     200.900287
# delta                      18.223874
# u                           22.37937
# g                            20.7792
# r                            19.1188
# i                           18.48122
# z                           18.12496
# run_ID                          5314
# rerun_ID                         301
# cam_col                            1
# field_ID                         156
# spec_obj_ID    6604653749360416768.0
# class                         GALAXY
# redshift                    0.360564
# plate                           5866
# MJD                            56035
# fiber_ID                         454
# Name: 74583, dtype: object
# Row:  obj_ID         1237664669505290496.0
# alpha                     145.283083
# delta                      33.686724
# u                           21.79444
# g                            19.1242
# r                            17.6341
# i                           17.07675
# z                           16.70001
# run_ID                          4469
# rerun_ID                         301
# cam_col                            5
# field_ID                         234
# spec_obj_ID    2189973781924046848.0
# class                         GALAXY
# redshift                     0.25171
# plate                           1945
# MJD                            53387
# fiber_ID                         358
# Name: 27775, dtype: object
# Row:  obj_ID         1237663789038043648.0
# alpha                     145.391611
# delta                      68.597701
# u                           22.70067
# g                           20.92798
# r                           19.05924
# i                           18.17503
# z                           17.71553
# run_ID                          4264
# rerun_ID                         301
# cam_col                            5
# field_ID                         250
# spec_obj_ID    2115653961015912448.0
# class                         GALAXY
# redshift                    0.448148
# plate                           1879
# MJD                            54478
# fiber_ID                         320
# Name: 23005, dtype: object
# Row:  obj_ID         1237651539793019136.0
# alpha                     222.814574
# delta                      63.262349
# u                           23.35443
# g                           22.65788
# r                           20.53019
# i                           19.31707
# z                           18.82104
# run_ID                          1412
# rerun_ID                         301
# cam_col                            5
# field_ID                         276
# spec_obj_ID    7862392528989083648.0
# class                         GALAXY
# redshift                    0.607921
# plate                           6983
# MJD                            56447
# fiber_ID                         849
# Name: 47817, dtype: object
# Row:  obj_ID         1237661360765862656.0
# alpha                     216.445206
# delta                      42.216378
# u                           22.62471
# g                           21.90065
# r                           20.28751
# i                           19.21159
# z                           18.64339
# run_ID                          3699
# rerun_ID                         301
# cam_col                            2
# field_ID                         173
# spec_obj_ID    6823062389023593472.0
# class                         GALAXY
# redshift                    0.577553
# plate                           6060
# MJD                            56074
# fiber_ID                         396
# Name: 12392, dtype: object
# Row:  obj_ID         1237667485916791296.0
# alpha                     132.648151
# delta                      15.869776
# u                            23.9385
# g                           21.53206
# r                           19.62689
# i                           18.86309
# z                           18.58794
# run_ID                          5125
# rerun_ID                         301
# cam_col                            3
# field_ID                          31
# spec_obj_ID    5958384452224964608.0
# class                         GALAXY
# redshift                    0.434531
# plate                           5292
# MJD                            55926
# fiber_ID                         444
# Name: 27362, dtype: object
# Image retrieval and saving complete.

# %% [markdown]
# # Rename Images sequentially

# %%
import os
from tqdm.auto import tqdm

tqdm.pandas()

# Function to rename images sequentially
def rename_images_sequentially(directory):
    files = os.listdir(directory)
    for i, filename in enumerate(sorted(files), 1):
        os.rename(
            os.path.join(directory, filename),
            os.path.join(directory, f'{i + 111}.jpg')
        )

# dir1 = 'galaxy_images/'
# rename_images_sequentially(dir1)

dir2 = 'dataset/No-galaxy1/'
rename_images_sequentially(dir2)

print('Image renaming complete.')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 19
#      15 # dir1 = 'galaxy_images/'
#      16 # rename_images_sequentially(dir1)
#      18 dir2 = 'dataset/No-galaxy1/'
# ---> 19 rename_images_sequentially(dir2)
#      21 print('Image renaming complete.')
#
# Cell In[7], line 10, in rename_images_sequentially(directory)
#       8 files = os.listdir(directory)
#       9 for i, filename in enumerate(sorted(files), 1):
# ---> 10     os.rename(
#      11         os.path.join(directory, filename),
#      12         os.path.join(directory, f'{i}.jpg')
#      13     )
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'dataset/No-galaxy1/18.jpg' -> 'dataset/No-galaxy1/2.jpg'

# %%
from astroquery.sdss import SDSS
from astropy import coordinates as coords
import astropy.units as u

# Define a coordinate object for the center of the search
# For example, let's use the location of the Coma Cluster
coma_cluster = coords.SkyCoord(194.9531, 27.9807, unit=(u.deg, u.deg), frame='icrs')


# Define the query to select galaxies within 0.1 degrees from the Coma Cluster
query = """
SELECT TOP 5
  p.objID, p.ra, p.dec, p.u, p.g, p.r, p.i, p.z, s.class
FROM PhotoObj AS p
  JOIN dbo.fGetNearbyObjEq({ra},{dec},3) AS n ON n.objID = p.objID
  JOIN SpecObj AS s ON s.bestobjid = p.objid
WHERE
  s.class = "QSO"
""".format(ra=coma_cluster.ra.deg, dec=coma_cluster.dec.deg)

# Execute the query
results = SDSS.query_sql(query)

# Display the results
print(results)
# Out:
# None

# %%
import os
from astroquery.sdss import SDSS
from astropy.coordinates import SkyCoord
import astropy.units as u

# Create a directory for galaxy images if it doesn't exist
os.makedirs('data', exist_ok=True)

# Function to download images
def download_images(table):
    for row in table:
        coords = SkyCoord(ra=row['ra']*u.deg, dec=row['dec']*u.deg, frame='icrs')
        images = SDSS.get_images(coordinates=coords, band='g', timeout=30)
        for image in images:
            image.writeto(f'data/{row["objID"]}.fits', overwrite=True)

# Call the function to download images
print('Downloading images...')
# Using the previously obtained results
# Note: The variable 'results' should contain the result from the previous query
# If the variable is not available, we need to re-run the query
if 'results' in locals():
    download_images(results)
else:
    print('Query results not found. Please re-run the query.')
print('Download complete.')
# Out:
# Downloading images...
# Download complete.

# %%
coords = SkyCoord(ra= [135.6891066]
, dec= [32.49463184]
, frame='icrs')

images = SDSS.get_images(coordinates=coords, band='g', timeout=30)
for image in images:
    image.writeto(f'data/test.fits', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# UnitTypeError                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 coords = SkyCoord(ra= [135.6891066]
#       2 , dec= [32.49463184]
#       3 , frame='icrs')
#       5 images = SDSS.get_images(coordinates=coords, band='g', timeout=30)
#       6 for image in images:
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\sky_coordinate.py:331, in SkyCoord.__init__(self, copy, *args, **kwargs)
#     327 # Parse the args and kwargs to assemble a sanitized and validated
#     328 # kwargs dict for initializing attributes for this object and for
#     329 # creating the internal self._sky_coord_frame object
#     330 args = list(args)  # Make it mutable
# --> 331 skycoord_kwargs, components, info = _parse_coordinate_data(
#     332     frame_cls(**frame_kwargs), args, kwargs)
#     334 # In the above two parsing functions, these kwargs were identified
#     335 # as valid frame attributes for *some* frame, but not the frame that
#     336 # this SkyCoord will have. We keep these attributes as special
#     337 # skycoord frame attributes:
#     338 for attr in skycoord_kwargs:
#     339     # Setting it will also validate it.
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\sky_coordinate_parsers.py:240, in _parse_coordinate_data(frame, args, kwargs)
#     236 units = _get_representation_component_units(args, kwargs)
#     238 # Grab any frame-specific attr names like `ra` or `l` or `distance` from
#     239 # kwargs and move them to valid_components.
# --> 240 valid_components.update(_get_representation_attrs(frame, units, kwargs))
#     242 # Error if anything is still left in kwargs
#     243 if kwargs:
#     244     # The next few lines add a more user-friendly error message to a
#     245     # common and confusing situation when the user specifies, e.g.,
#     246     # `pm_ra` when they really should be passing `pm_ra_cosdec`. The
#     247     # extra error should only turn on when the positional representation
#     248     # is spherical, and when the component 'pm_<lon>' is passed.
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\sky_coordinate_parsers.py:588, in _get_representation_attrs(frame, units, kwargs)
#     586 if value is not None:
#     587     try:
# --> 588         valid_kwargs[frame_attr_name] = repr_attr_class(value, unit=unit)
#     589     except u.UnitConversionError as err:
#     590         error_message = (
#     591             f"Unit '{unit}' ({unit.physical_type}) could not be applied to '{frame_attr_name}'. "
#     592             "This can occur when passing units for some coordinate components "
#    (...)
#     595             "or pass Quantities for all components."
#     596         )
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\angles.py:679, in Longitude.__new__(cls, angle, unit, wrap_angle, **kwargs)
#     676 if isinstance(angle, Latitude):
#     677     raise TypeError("A Longitude angle cannot be created from "
#     678                     "a Latitude angle.")
# --> 679 self = super().__new__(cls, angle, unit=unit, **kwargs)
#     680 if wrap_angle is None:
#     681     wrap_angle = getattr(angle, 'wrap_angle', self._default_wrap_angle)
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\angles.py:140, in Angle.__new__(cls, angle, unit, dtype, copy, **kwargs)
#     135             angle = u.Quantity(angle, angle_unit, copy=False)
#     137     elif (isiterable(angle) and
#     138           not (isinstance(angle, np.ndarray) and
#     139                angle.dtype.kind not in 'SUVO')):
# --> 140         angle = [Angle(x, unit, copy=False) for x in angle]
#     142 return super().__new__(cls, angle, unit, dtype=dtype, copy=copy,
#     143                        **kwargs)
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\angles.py:140, in <listcomp>(.0)
#     135             angle = u.Quantity(angle, angle_unit, copy=False)
#     137     elif (isiterable(angle) and
#     138           not (isinstance(angle, np.ndarray) and
#     139                angle.dtype.kind not in 'SUVO')):
# --> 140         angle = [Angle(x, unit, copy=False) for x in angle]
#     142 return super().__new__(cls, angle, unit, dtype=dtype, copy=copy,
#     143                        **kwargs)
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\angles.py:142, in Angle.__new__(cls, angle, unit, dtype, copy, **kwargs)
#     137     elif (isiterable(angle) and
#     138           not (isinstance(angle, np.ndarray) and
#     139                angle.dtype.kind not in 'SUVO')):
#     140         angle = [Angle(x, unit, copy=False) for x in angle]
# --> 142 return super().__new__(cls, angle, unit, dtype=dtype, copy=copy,
#     143                        **kwargs)
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\units\quantity.py:523, in Quantity.__new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     520         cls = qcls
#     522 value = value.view(cls)
# --> 523 value._set_unit(value_unit)
#     524 if unit is value_unit:
#     525     return value
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\coordinates\angles.py:164, in Angle._set_unit(self, unit)
#     163 def _set_unit(self, unit):
# --> 164     super()._set_unit(self._convert_unit_to_angle_unit(unit))
#
# File d:\Software\anaconda3\Lib\site-packages\astropy\units\quantity.py:1938, in SpecificTypeQuantity._set_unit(self, unit)
#    1936 def _set_unit(self, unit):
#    1937     if unit is None or not unit.is_equivalent(self._equivalent_unit):
# -> 1938         raise UnitTypeError(
#    1939             "{} instances require units equivalent to '{}'"
#    1940             .format(type(self).__name__, self._equivalent_unit) +
#    1941             (", but no unit was given." if unit is None else
#    1942              f", so cannot set it to '{unit}'."))
#    1944     super()._set_unit(unit)
#
# UnitTypeError: Angle instances require units equivalent to 'rad', but no unit was given.
